# %% [markdown]
# ## Bronze Layer
#
# ### Goal:
# - find all type of information to recolt
#     - yahoo finance  (What else ?) ou FMP
#     - Fred for macros
#     - Financial statement  & Income Statement from ... ou FMP
#     - Corporate Actions ou FMP
#     - FX (Currency Data) ou FMP
#
# - Store in aws data lake
#     - This will be called the bronze layer
#     - This will be used to create the silver layer

# %% [markdown]
# ## Steps:
#
# - Fetch datas in a table format
# - Fetch data in a no sql format
# - test with aws
#     - Connection
#     - testing
#     - See the possible optimzation
# - Store the value in aws
# - Pass to the silver infrastructure
