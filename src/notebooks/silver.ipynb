# %% [markdown]
# ## Silver pour yahoo finance !
# ### Analyse des opérations à faire avec polars
# - Travail sur Date (colonne)
# - travail sur la normalisation des colonnes
# - Travail sur des exercises de nettoyage de la données
#     - Quels sont les nettoyages necessaires pour yf
# - Travail sur le lazy loading
# - Travail sur le get boto3 pour s3
# - travail pour le stockage parquet sur s3

# %%
# imports

# !pip install boto3
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#   Using cached jmespath-1.1.0-py3-none-any.whl.metadata (7.6 kB)
# ...
#   Using cached s3transfer-0.16.0-py3-none-any.whl.metadata (1.7 kB)
# ...
#    ---------------------------------------- 0.0/14.6 MB ? eta -:--:--
#    ---- ----------------------------------- 1.6/14.6 MB 9.1 MB/s eta 0:00:02
#    ----------- ---------------------------- 4.2/14.6 MB 10.3 MB/s eta 0:00:02
#    --------------- ------------------------ 5.5/14.6 MB 9.0 MB/s eta 0:00:02
#    -------------------- ------------------- 7.3/14.6 MB 9.0 MB/s eta 0:00:01
#    ------------------------- -------------- 9.4/14.6 MB 9.4 MB/s eta 0:00:01
#    ------------------------------- -------- 11.5/14.6 MB 9.5 MB/s eta 0:00:01
#    -------------------------------------- - 13.9/14.6 MB 9.6 MB/s eta 0:00:01
#    ---------------------------------------- 14.6/14.6 MB 9.3 MB/s  0:00:01
# Using cached jmespath-1.1.0-py3-none-any.whl (20 kB)
# ...

# %%
# Les imports importants pour le cleaning silver
import gzip

import polars as pl 
from datetime import datetime
from zoneinfo import zoneinfo
from pathlib import Path
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 2
#       1 # Les imports importants pour le cleaning silver
# ----> 2 import boto3
#       3 import gzip
#       6 import polars as pl
#
# ModuleNotFoundError: No module named 'boto3'
